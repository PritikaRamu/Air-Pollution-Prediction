# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score,mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Alcantarilla

# %%
alc = pd.read_csv('alc.csv')
alc
# Out:
#        DD (grados)  HR (% H.R.)  Hour         Month  NO (µg/m³N)  \
# 0            265.0         39.0    12  2.582276e-02          4.0
# 1            248.0         36.8    13  2.797466e-02          3.0
# 2            128.0         39.4    14  3.012655e-02          4.0
# 3            185.0         33.6    15  3.227844e-02          4.0
# 4            232.0         33.6    16  3.443033e-02          2.0
# ...            ...          ...   ...           ...          ...
# 17503        335.0         76.0    19  8.607594e-03         15.0
# 17504        282.0         81.0    20  6.455696e-03         39.0
# 17505        320.0         85.0    21  4.303797e-03         84.0
# 17506        148.0         87.0    22  2.151899e-03         80.0
# 17507        326.0         88.0    23  1.469576e-15         45.0
#
#        NO2 (µg/m³N)  NOX (µg/m³N)  O3 (µg/m³N)  PM10 (µg/m³N)  RS (W/m³)  ...  \
# 0              10.0          15.0         71.0            5.0      350.0  ...
# 1              10.0          14.0         77.0            7.0      474.0  ...
# 2              11.0          17.0         77.0            8.0      482.0  ...
# 3               8.0          14.0         82.0            4.0      455.0  ...
# 4               9.0          12.0         87.0            9.0      368.0  ...
# ...             ...           ...          ...            ...        ...  ...
# 17503          49.0          72.0          4.0           40.0        2.0  ...
# 17504          56.0         115.0          3.0           50.0        1.0  ...
# 17505          63.0         191.0          2.0           43.0        2.0  ...
# 17506          57.0         180.0          2.0           41.0        1.0  ...
# 17507          39.0         107.0          2.0           42.0        1.0  ...
#
#        NO_lag1  NO2_lag1  NOX_lag1 PM10_lag1  O3_lag1  NO_lag2  NO2_lag2  \
# 0          5.0      11.0      18.0       7.0     69.0      5.0      20.0
# 1          4.0      10.0      15.0       5.0     71.0      5.0      11.0
# 2          3.0      10.0      14.0       7.0     77.0      4.0      10.0
# 3          4.0      11.0      17.0       8.0     77.0      3.0      10.0
# 4          4.0       8.0      14.0       4.0     82.0      4.0      11.0
# ...        ...       ...       ...       ...      ...      ...       ...
# 17503      3.0      31.0      36.0      32.0     31.0      3.0      18.0
# 17504     15.0      49.0      72.0      40.0      4.0      3.0      31.0
# 17505     39.0      56.0     115.0      50.0      3.0     15.0      49.0
# 17506     84.0      63.0     191.0      43.0      2.0     39.0      56.0
# 17507     80.0      57.0     180.0      41.0      2.0     84.0      63.0
#
#        NOX_lag2  PM10_lag2  O3_lag2
# 0          27.0       11.0     46.0
# 1          18.0        7.0     69.0
# 2          15.0        5.0     71.0
# 3          14.0        7.0     77.0
# 4          17.0        8.0     77.0
# ...         ...        ...      ...
# 17503      22.0       26.0     49.0
# 17504      36.0       32.0     31.0
# 17505      72.0       40.0      4.0
# 17506     115.0       50.0      3.0
# 17507     191.0       43.0      2.0
#
# [17508 rows x 29 columns]

# %%
x = alc[['NOX (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)','Month','Hour']]
y = alc[['NO (µg/m³N)']]

# %%
x_train = x[5000:]
y_train = y[5000:]
x_test = x[:5000]
y_test = y[:5000]

# %%
rf = RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# <ipython-input-41-895403b03771>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# RandomForestRegressor()

# %%
y_pred = rf.predict(x_test)
y_pred
# Out:
# array([2.83, 2.62, 3.29, ..., 1.18, 1.02, 1.05])

# %%
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
score = rf.score(x,y)
acc = rf.score(x_test,y_test)
print('R-squared:',score,'\n','RMSE: ',rmse,'\n','Accuracy: ',acc)
# Out:
# R-squared: 0.9991204580190945
#  RMSE:  0.907677295518622
#  Accuracy:  0.9966196817302163

# %%
plt.figure(figsize=(50,10))
plt.plot(np.array(y_test),'--')
plt.plot(y_pred)
plt.legend(['Actual','Predicted'])

# %%
#list_x = [['NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)','Month','Hour'],['NOX (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)','Month','Hour'],['NOX (µg/m³N)','NO (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)','Month','Hour'],['NOX (µg/m³N)','NO (µg/m³N)','NO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)','Month','Hour'],['NOX (µg/m³N)','NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)','Month','Hour'],['NOX (µg/m³N)','NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','Month','Hour']]
#list_y = ['NOX (µg/m³N)','NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','PM10 (µg/m³N)']
list_x = [['NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)'],['NOX (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)'],['NOX (µg/m³N)','NO (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)'],['NOX (µg/m³N)','NO (µg/m³N)','NO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)'],['NOX (µg/m³N)','NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)'],['NOX (µg/m³N)','NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)']]
list_y = ['NOX (µg/m³N)','NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','PM10 (µg/m³N)']
for i in np.arange(0,6):
    x = alc[list_x[i]]
    y = alc[[list_y[i]]]
    x_train = x[5000:]
    y_train = y[5000:]
    x_test = x[:5000]
    y_test = y[:5000]
    rf.fit(x_train,y_train)  
    y_pred = rf.predict(x_test)
#     importance = rf.feature_importances_
#     for j,v in enumerate(importance):
#         print('Feature: %0d, Score: %.5f' % (j,v))
    mse = mean_squared_error(y_test,y_pred)
    rmse = np.sqrt(mse)
    score = rf.score(x,y)
    print(list_y[i],'\n R-squared:',score,'\n','RMSE: ',rmse)
# Out:
# <ipython-input-45-d71bdd236a3d>:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# NOX (µg/m³N)
#  R-squared: 0.9996543476577016
#  RMSE:  1.1821762650298813
# <ipython-input-45-d71bdd236a3d>:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# NO (µg/m³N)
#  R-squared: 0.9991220950365746
#  RMSE:  0.8909238252510705
# <ipython-input-45-d71bdd236a3d>:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# NO2 (µg/m³N)
#  R-squared: 0.9955966072143744
#  RMSE:  1.8087144185857535
# <ipython-input-45-d71bdd236a3d>:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# SO2 (µg/m³N)
#  R-squared: 0.7270666832970316
#  RMSE:  1.184868191150391
# <ipython-input-45-d71bdd236a3d>:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# O3 (µg/m³N)
#  R-squared: 0.9444222306317791
#  RMSE:  14.341960961988427
# <ipython-input-45-d71bdd236a3d>:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# PM10 (µg/m³N)
#  R-squared: 0.7751243370806347
#  RMSE:  11.406382303465021

# %% [markdown]
# # Aljorra

# %%
alc = pd.read_csv('al.csv')
alc
# Out:
#        DD (grados)  HR (% H.R.)  Hour         Month  NO (µg/m³N)  \
# 0            282.0         47.0     0  0.000000e+00          3.0
# 1            319.0         49.0     1  2.151899e-03          4.0
# 2            329.0         44.0     2  4.303797e-03          3.0
# 3            327.0         47.0     3  6.455696e-03          3.0
# 4            330.0         51.0     4  8.607594e-03          3.0
# ...            ...          ...   ...           ...          ...
# 17515        158.0         87.0    19  8.607594e-03          3.0
# 17516        245.0         94.0    20  6.455696e-03          6.0
# 17517        317.0         98.0    21  4.303797e-03         15.0
# 17518        306.0        100.0    22  2.151899e-03          3.0
# 17519        315.0        100.0    23  1.469576e-15          2.0
#
#        NO2 (µg/m³N)  NOX (µg/m³N)  O3 (µg/m³N)  PM10 (µg/m³N)  RS (W/m³)  \
# 0               8.0          13.0         70.0           41.0        2.0
# 1               8.0          13.0         66.0           62.0        2.0
# 2               7.0          12.0         78.0          103.0        1.0
# 3               8.0          13.0         77.0           18.0        1.0
# 4              10.0          15.0         74.0            5.0        1.0
# ...             ...           ...          ...            ...        ...
# 17515          18.0          22.0         43.0           39.0        2.0
# 17516          29.0          38.0         19.0           36.0        2.0
# 17517          31.0          54.0          5.0           53.0        2.0
# 17518          23.0          28.0          9.0           26.0        3.0
# 17519          16.0          18.0         15.0           21.0        3.0
#
#        SO2 (µg/m³N)  TMP (ºC)  VV (m/s)                 Date
# 0               7.0      19.0       1.0  2018-01-01 00:00:00
# 1               8.0      18.0       2.0  2018-01-01 01:00:00
# 2              10.0      17.0       3.0  2018-01-01 02:00:00
# 3              11.0      16.0       1.0  2018-01-01 03:00:00
# 4               9.0      15.0       1.0  2018-01-01 04:00:00
# ...             ...       ...       ...                  ...
# 17515           7.0      13.0       1.0  2019-12-31 19:00:00
# 17516           9.0      12.0       1.0  2019-12-31 20:00:00
# 17517          11.0      11.0       1.0  2019-12-31 21:00:00
# 17518           8.0       9.0       1.0  2019-12-31 22:00:00
# 17519           6.0       9.0       1.0  2019-12-31 23:00:00
#
# [17520 rows x 14 columns]

# %%
list_x = [['NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)','Month','Hour'],['NOX (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)','Month','Hour'],['NOX (µg/m³N)','NO (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)','Month','Hour'],['NOX (µg/m³N)','NO (µg/m³N)','NO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)','Month','Hour'],['NOX (µg/m³N)','NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)','Month','Hour'],['NOX (µg/m³N)','NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','Month','Hour']]
list_y = ['NOX (µg/m³N)','NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','PM10 (µg/m³N)']
#list_x = [['NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)'],['NOX (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)'],['NOX (µg/m³N)','NO (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)'],['NOX (µg/m³N)','NO (µg/m³N)','NO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)'],['NOX (µg/m³N)','NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)'],['NOX (µg/m³N)','NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)']]
#list_y = ['NOX (µg/m³N)','NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','PM10 (µg/m³N)']
for i in np.arange(0,6):
    x = alc[list_x[i]]
    y = alc[[list_y[i]]]
    x_train = x[5000:]
    y_train = y[5000:]
    x_test = x[:5000]
    y_test = y[:5000]
    rf.fit(x_train,y_train)  
    y_pred = rf.predict(x_test)
#     importance = rf.feature_importances_
#     for j,v in enumerate(importance):
#         print('Feature: %0d, Score: %.5f' % (j,v))
    mse = mean_squared_error(y_test,y_pred)
    rmse = np.sqrt(mse)
    score = rf.score(x,y)
    print(list_y[i],'\n R-squared:',score,'\n','RMSE: ',rmse)
# Out:
# <ipython-input-46-c5ab491418d7>:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# NOX (µg/m³N)
#  R-squared: 0.9996682866710022
#  RMSE:  1.187577314704184
# <ipython-input-46-c5ab491418d7>:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# NO (µg/m³N)
#  R-squared: 0.9991032684780207
#  RMSE:  0.923570131608856
# <ipython-input-46-c5ab491418d7>:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# NO2 (µg/m³N)
#  R-squared: 0.9938075348385267
#  RMSE:  2.297888579370201
# <ipython-input-46-c5ab491418d7>:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# SO2 (µg/m³N)
#  R-squared: 0.5931066198103978
#  RMSE:  1.5953879686145311
# <ipython-input-46-c5ab491418d7>:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# O3 (µg/m³N)
#  R-squared: 0.9113418118955064
#  RMSE:  18.836134268984175
# <ipython-input-46-c5ab491418d7>:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# PM10 (µg/m³N)
#  R-squared: 0.7770664090377928
#  RMSE:  11.661384725837664

# %% [markdown]
# # Time Series

# %%
alc = pd.read_csv('alc.csv')
alc
# Out:
#        DD (grados)  HR (% H.R.)  Hour         Month  NO (µg/m³N)  \
# 0            265.0         39.0    12  2.582276e-02          4.0
# 1            248.0         36.8    13  2.797466e-02          3.0
# 2            128.0         39.4    14  3.012655e-02          4.0
# 3            185.0         33.6    15  3.227844e-02          4.0
# 4            232.0         33.6    16  3.443033e-02          2.0
# ...            ...          ...   ...           ...          ...
# 17503        335.0         76.0    19  8.607594e-03         15.0
# 17504        282.0         81.0    20  6.455696e-03         39.0
# 17505        320.0         85.0    21  4.303797e-03         84.0
# 17506        148.0         87.0    22  2.151899e-03         80.0
# 17507        326.0         88.0    23  1.469576e-15         45.0
#
#        NO2 (µg/m³N)  NOX (µg/m³N)  O3 (µg/m³N)  PM10 (µg/m³N)  RS (W/m³)  ...  \
# 0              10.0          15.0         71.0            5.0      350.0  ...
# 1              10.0          14.0         77.0            7.0      474.0  ...
# 2              11.0          17.0         77.0            8.0      482.0  ...
# 3               8.0          14.0         82.0            4.0      455.0  ...
# 4               9.0          12.0         87.0            9.0      368.0  ...
# ...             ...           ...          ...            ...        ...  ...
# 17503          49.0          72.0          4.0           40.0        2.0  ...
# 17504          56.0         115.0          3.0           50.0        1.0  ...
# 17505          63.0         191.0          2.0           43.0        2.0  ...
# 17506          57.0         180.0          2.0           41.0        1.0  ...
# 17507          39.0         107.0          2.0           42.0        1.0  ...
#
#        NO_lag1  NO2_lag1  NOX_lag1 PM10_lag1  O3_lag1  NO_lag2  NO2_lag2  \
# 0          5.0      11.0      18.0       7.0     69.0      5.0      20.0
# 1          4.0      10.0      15.0       5.0     71.0      5.0      11.0
# 2          3.0      10.0      14.0       7.0     77.0      4.0      10.0
# 3          4.0      11.0      17.0       8.0     77.0      3.0      10.0
# 4          4.0       8.0      14.0       4.0     82.0      4.0      11.0
# ...        ...       ...       ...       ...      ...      ...       ...
# 17503      3.0      31.0      36.0      32.0     31.0      3.0      18.0
# 17504     15.0      49.0      72.0      40.0      4.0      3.0      31.0
# 17505     39.0      56.0     115.0      50.0      3.0     15.0      49.0
# 17506     84.0      63.0     191.0      43.0      2.0     39.0      56.0
# 17507     80.0      57.0     180.0      41.0      2.0     84.0      63.0
#
#        NOX_lag2  PM10_lag2  O3_lag2
# 0          27.0       11.0     46.0
# 1          18.0        7.0     69.0
# 2          15.0        5.0     71.0
# 3          14.0        7.0     77.0
# 4          17.0        8.0     77.0
# ...         ...        ...      ...
# 17503      22.0       26.0     49.0
# 17504      36.0       32.0     31.0
# 17505      72.0       40.0      4.0
# 17506     115.0       50.0      3.0
# 17507     191.0       43.0      2.0
#
# [17508 rows x 29 columns]

# %%
#list_x = [['NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)','Month','Hour'],['NOX (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)','Month','Hour'],['NOX (µg/m³N)','NO (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)','Month','Hour'],['NOX (µg/m³N)','NO (µg/m³N)','NO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)','Month','Hour'],['NOX (µg/m³N)','NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)','Month','Hour'],['NOX (µg/m³N)','NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','Month','Hour']]
#list_y = ['NOX (µg/m³N)','NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','PM10 (µg/m³N)']
list_x = ['DD (grados)', 'HR (% H.R.)', 'Hour', 'Month', 'RS (W/m³)', 'TMP (ºC)', 'VV (m/s)', 'NO_roll_mean', 'NO2_roll_mean', 'NOX_roll_mean', 'PM10_roll_mean', 'O3_roll_mean', 'NO_lag1', 'NO2_lag1', 'NOX_lag1', 'PM10_lag1', 'O3_lag1', 'NO_lag2', 'NO2_lag2', 'NOX_lag2', 'PM10_lag2', 'O3_lag2']
list_y = ['NOX (µg/m³N)','NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','PM10 (µg/m³N)']
for i in np.arange(0,6):
    x = alc[list_x]
    y = alc[[list_y[i]]]
    x_train = x[5000:]
    y_train = y[5000:]
    x_test = x[:5000]
    y_test = y[:5000]
    rf.fit(x_train,y_train)  
    y_pred = rf.predict(x_test)
#     importance = rf.feature_importances_
#     for j,v in enumerate(importance):
#         print('Feature: %0d, Score: %.5f' % (j,v))
    mse = mean_squared_error(y_test,y_pred)
    rmse = np.sqrt(mse)
    score = rf.score(x,y)
    print(list_y[i],'\n R-squared:',score,'\n','RMSE: ',rmse)
# Out:
# <ipython-input-36-2bb5878ccd8c>:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# NOX (µg/m³N)
#  R-squared: 0.9474356481109144
#  RMSE:  15.133501012019657
# <ipython-input-36-2bb5878ccd8c>:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# NO (µg/m³N)
#  R-squared: 0.9362669574160271
#  RMSE:  7.4992353222445285
# <ipython-input-36-2bb5878ccd8c>:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# NO2 (µg/m³N)
#  R-squared: 0.9436516328749867
#  RMSE:  6.694287043502094
# <ipython-input-36-2bb5878ccd8c>:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# SO2 (µg/m³N)
#  R-squared: 0.5837723826416632
#  RMSE:  1.6059982176826972
# <ipython-input-36-2bb5878ccd8c>:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# O3 (µg/m³N)
#  R-squared: 0.9777007401189305
#  RMSE:  8.724911205783128
# <ipython-input-36-2bb5878ccd8c>:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# PM10 (µg/m³N)
#  R-squared: 0.878057713744562
#  RMSE:  8.035216712099306
