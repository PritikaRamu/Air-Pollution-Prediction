# %%
import pandas as pd 
from datetime import datetime
import numpy as np 
from sklearn.linear_model import Lasso
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error, accuracy_score

# %%
alc = pd.read_csv('alc.csv')
alc
# Out:
#                       Date  Hour  Month  NO (µg/m³N)  NO2 (µg/m³N)  \
# 0      2018-01-01 00:00:00     0      1          3.0           9.0
# 1      2018-01-01 01:00:00     1      1          3.0           8.0
# 2      2018-01-01 02:00:00     2      1          2.0          11.0
# 3      2018-01-01 03:00:00     3      1          4.0           9.0
# 4      2018-01-01 04:00:00     4      1          3.0           9.0
# ...                    ...   ...    ...          ...           ...
# 17515  2019-12-31 19:00:00    19     12         15.0          49.0
# 17516  2019-12-31 20:00:00    20     12         39.0          56.0
# 17517  2019-12-31 21:00:00    21     12         84.0          63.0
# 17518  2019-12-31 22:00:00    22     12         80.0          57.0
# 17519  2019-12-31 23:00:00    23     12         45.0          39.0
#
#        NOX (µg/m³N)  O3 (µg/m³N)  PM10 (µg/m³N)  RS (W/m³)  SO2 (µg/m³N)  \
# 0              14.0         73.0           25.0        1.0           2.0
# 1              12.0         83.0           63.0        1.0           3.0
# 2              14.0         80.0            8.0        1.0           3.0
# 3              14.0         80.0            7.0        1.0           3.0
# 4              14.0         76.0            6.0        1.0           3.0
# ...             ...          ...            ...        ...           ...
# 17515          72.0          4.0           40.0        2.0           1.0
# 17516         115.0          3.0           50.0        1.0           1.0
# 17517         191.0          2.0           43.0        2.0           2.0
# 17518         180.0          2.0           41.0        1.0           2.0
# 17519         107.0          2.0           42.0        1.0           2.0
#
#        TMP (ºC)  VV (m/s)  DD (grados)  HR (% H.R.)
# 0          17.0       4.0        307.0         56.6
# 1          17.0       6.0        297.0         44.6
# 2          16.0       3.0        297.0         46.2
# 3          15.0       2.0        302.0         52.6
# 4          13.0       0.0        155.0         62.2
# ...         ...       ...          ...          ...
# 17515      11.0       0.4        335.0         76.0
# 17516      10.0       0.4        282.0         81.0
# 17517       8.0       0.4        320.0         85.0
# 17518       7.0       0.4        148.0         87.0
# 17519       7.0       0.3        326.0         88.0
#
# [17520 rows x 14 columns]

# %%
x = alc[['NOX (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)','Month','Hour']]
y = alc[['NO (µg/m³N)']]

# %%
x_train = x[:12000]
y_train = y[:12000]
x_test = x[12000:]
y_test = y[12000:]

# %%
lr = Lasso(alpha=-0.00001, normalize=True)
lr.fit(x_train,y_train)
# Out:
# /home/pritika/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2954.166122742188, tolerance: 538.4024819719997
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=-1e-05, normalize=True)

# %%
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([ 1.39508573,  0.74214872,  0.72675623, ..., 83.48959535,
#        80.24821649, 44.30494561])

# %%
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
score = lr.score(x,y)
acc = lr.score(x_test,y_test)
print('R-squared:',score,'\n','RMSE: ',rmse,'\n','Accuracy: ',acc)
# Out:
# R-squared: 0.999576614110573
#  RMSE:  0.42221863637074103
#  Accuracy:  0.999426694129993

# %%
plt.figure(figsize=(50,10))
plt.plot(np.array(y_test),'--')
plt.plot(y_pred)
plt.legend(['Actual','Predicted'])
