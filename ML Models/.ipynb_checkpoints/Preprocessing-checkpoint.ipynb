# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import math

# %% [markdown]
# # Alcantarilla (18-19)

# %%
df_18 = pd.read_csv('Alcantarillahorarias2018.csv', header=1)
df_18= df_18.drop(['PRB (mb)','C6H6 (µg/m³N)','C7H8 (µg/m³N)','XIL (µg/m³N)'],axis =1)
df_18.rename(columns = {'Fecha':'Date'}, inplace = True)

# %%
plt.figure(figsize=(16, 6))
sns.heatmap(df_18.corr(method='pearson'), vmin=-1, vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %%
fig, axs = plt.subplots(4, 3)

axs[0, 0].plot(df_18['Date'],df_18['NO (µg/m³N)'])
axs[0, 0].set_title('NO (µg/m³N)')

axs[0, 1].plot(df_18['Date'],df_18['NO2 (µg/m³N)'], 'tab:orange')
axs[0, 1].set_title('NO2 (µg/m³N)')

axs[0, 2].plot(df_18['Date'],df_18['SO2 (µg/m³N)'], 'tab:green')
axs[0, 2].set_title('SO2 (µg/m³N)')

axs[1, 0].plot(df_18['Date'],df_18['O3 (µg/m³N)'], 'tab:red')
axs[1, 0].set_title('O3 (µg/m³N)')

axs[1, 1].plot(df_18['Date'],df_18['NOX (µg/m³N)'], 'tab:purple')
axs[1, 1].set_title('NOX (µg/m³N)')

axs[1, 2].plot(df_18['Date'],df_18['HR (% H.R.)'])
axs[1, 2].set_title('HR (% H.R.)')

axs[2, 0].plot(df_18['Date'],df_18['DD (grados)'])
axs[2, 0].set_title('DD (grados)')

axs[2, 1].plot(df_18['Date'],df_18['RS (W/m³)'], 'tab:orange')
axs[2, 1].set_title('RS (W/m³)')

axs[2, 2].plot(df_18['Date'],df_18['PM10 (µg/m³N)'], 'tab:green')
axs[2, 2].set_title('PM10 (µg/m³N)')

axs[3, 0].plot(df_18['Date'],df_18['TMP (ºC)'], 'tab:green')
axs[3, 0].set_title('TMP (ºC)')

axs[3, 1].plot(df_18['Date'],df_18['VV (m/s)'], 'tab:purple')
axs[3, 1].set_title('VV (m/s)')

for i in [0,1,2,3]:
    for j in [0,1,2]:
        axs[i, j].tick_params(axis='x',which='both', bottom=False, top=False, labelbottom=False)

# %%
df_19 = pd.read_csv('Alcantarillahorarias2019.csv', header=1)
df_19 = df_19.drop(['PRB (mb)','C6H6 (µg/m³N)','C7H8 (µg/m³N)','XIL (µg/m³N)'],axis =1)
df_19.rename(columns = {'Fecha':'Date'}, inplace = True)

# %%
plt.figure(figsize=(16, 6))
sns.heatmap(df_19.corr(method='pearson'), vmin=-1, vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %%
fig, axs = plt.subplots(4, 3)

axs[0, 0].plot(df_19['Date'],df_19['NO (µg/m³N)'])
axs[0, 0].set_title('NO (µg/m³N)')

axs[0, 1].plot(df_19['Date'],df_19['NO2 (µg/m³N)'], 'tab:orange')
axs[0, 1].set_title('NO2 (µg/m³N)')

axs[0, 2].plot(df_19['Date'],df_19['SO2 (µg/m³N)'], 'tab:green')
axs[0, 2].set_title('SO2 (µg/m³N)')

axs[1, 0].plot(df_19['Date'],df_19['O3 (µg/m³N)'], 'tab:red')
axs[1, 0].set_title('O3 (µg/m³N)')

axs[1, 1].plot(df_19['Date'],df_19['NOX (µg/m³N)'], 'tab:purple')
axs[1, 1].set_title('NOX (µg/m³N)')

axs[1, 2].plot(df_19['Date'],df_19['HR (% H.R.)'])
axs[1, 2].set_title('HR (% H.R.)')

axs[2, 0].plot(df_19['Date'],df_19['DD (grados)'])
axs[2, 0].set_title('DD (grados)')

axs[2, 1].plot(df_19['Date'],df_19['RS (W/m³)'], 'tab:orange')
axs[2, 1].set_title('RS (W/m³)')

axs[2, 2].plot(df_19['Date'],df_19['PM10 (µg/m³N)'], 'tab:green')
axs[2, 2].set_title('PM10 (µg/m³N)')

axs[3, 0].plot(df_19['Date'],df_19['TMP (ºC)'], 'tab:green')
axs[3, 0].set_title('TMP (ºC)')

axs[3, 1].plot(df_19['Date'],df_19['VV (m/s)'], 'tab:purple')
axs[3, 1].set_title('VV (m/s)')

for i in [0,1,2,3]:
    for j in [0,1,2]:
        axs[i, j].tick_params(axis='x',which='both', bottom=False, top=False, labelbottom=False)

# %%
alcantarilla = pd.concat([df_18,df_19])
d = pd.date_range(start ='1-1-2018', end ='1-1-2020', freq ='H')
alcantarilla['Date'] = d[:-1]
alcantarilla['Month'] = d[:-1].strftime("%m")
alcantarilla['Hour'] = d[:-1].strftime("%H")
alcantarilla.to_csv('alcantarilla.csv',index=False)
alcantarilla =  alcantarilla.reset_index()
alcantarilla = alcantarilla.drop('index',1)

# %%
fig, axs = plt.subplots(4, 3)
 
axs[0, 0].plot(alcantarilla['Date'],alcantarilla['NO (µg/m³N)'])
axs[0, 0].set_title('NO (µg/m³N)')

axs[0, 1].plot(alcantarilla['Date'],alcantarilla['NO2 (µg/m³N)'], 'tab:orange')
axs[0, 1].set_title('NO2 (µg/m³N)')

axs[0, 2].plot(alcantarilla['Date'],alcantarilla['SO2 (µg/m³N)'], 'tab:green')
axs[0, 2].set_title('SO2 (µg/m³N)')

axs[1, 0].plot(alcantarilla['Date'],alcantarilla['O3 (µg/m³N)'], 'tab:red')
axs[1, 0].set_title('O3 (µg/m³N)')

axs[1, 1].plot(alcantarilla['Date'],alcantarilla['NOX (µg/m³N)'], 'tab:purple')
axs[1, 1].set_title('NOX (µg/m³N)')

axs[1, 2].plot(alcantarilla['Date'],alcantarilla['HR (% H.R.)'])
axs[1, 2].set_title('HR (% H.R.)')

axs[2, 0].plot(alcantarilla['Date'],alcantarilla['DD (grados)'])
axs[2, 0].set_title('DD (grados)')

axs[2, 1].plot(alcantarilla['Date'],alcantarilla['RS (W/m³)'], 'tab:orange')
axs[2, 1].set_title('RS (W/m³)')

axs[2, 2].plot(alcantarilla['Date'],alcantarilla['PM10 (µg/m³N)'], 'tab:green')
axs[2, 2].set_title('PM10 (µg/m³N)')

axs[3, 0].plot(alcantarilla['Date'],alcantarilla['TMP (ºC)'], 'tab:green')
axs[3, 0].set_title('TMP (ºC)')

axs[3, 1].plot(alcantarilla['Date'],alcantarilla['VV (m/s)'], 'tab:purple')
axs[3, 1].set_title('VV (m/s)')

for i in [0,1,2,3]:
    for j in [0,1,2]:
        axs[i, j].tick_params(axis='x',which='both', bottom=False, top=False, labelbottom=False)

# %% [markdown]
# # Normalization

# %%
alc = alcantarilla.drop(columns=['Date','Month','Hour'])
normalized_alc=(alc-alc.min())/(alc.max()-alc.min())
normalized_alc
# Out:
#        NO (µg/m³N)  NO2 (µg/m³N)  SO2 (µg/m³N)  O3 (µg/m³N)  TMP (ºC)  \
# 0         0.006329      0.066667      0.028571     0.446541  0.404762
# 1         0.006329      0.057143      0.057143     0.509434  0.404762
# 2         0.003165      0.085714      0.057143     0.490566  0.380952
# 3         0.009494      0.066667      0.057143     0.490566  0.357143
# 4         0.006329      0.066667      0.057143     0.465409  0.309524
# ...            ...           ...           ...          ...       ...
# 17515     0.044304      0.447619      0.000000     0.012579  0.261905
# 17516     0.120253      0.514286      0.000000     0.006289  0.238095
# 17517     0.262658      0.580952      0.028571     0.000000  0.190476
# 17518     0.250000      0.523810      0.028571     0.000000  0.166667
# 17519     0.139241      0.352381      0.028571     0.000000  0.166667
#
#        HR (% H.R.)  NOX (µg/m³N)  DD (grados)  RS (W/m³)  VV (m/s)  \
# 0              NaN      0.019197     0.852778   0.000000      0.40
# 1              NaN      0.015707     0.825000   0.000000      0.60
# 2              NaN      0.019197     0.825000   0.000000      0.30
# 3              NaN      0.019197     0.838889   0.000000      0.20
# 4              NaN      0.019197     0.430556   0.000000      0.00
# ...            ...           ...          ...        ...       ...
# 17515     0.744186      0.120419     0.930556   0.001002      0.04
# 17516     0.802326      0.195462     0.783333   0.000000      0.04
# 17517     0.848837      0.328098     0.888889   0.001002      0.04
# 17518     0.872093      0.308901     0.411111   0.000000      0.04
# 17519     0.883721      0.181501     0.905556   0.000000      0.03
#
#        PM10 (µg/m³N)
# 0           0.063325
# 1           0.163588
# 2           0.018470
# 3           0.015831
# 4           0.013193
# ...              ...
# 17515       0.102902
# 17516       0.129288
# 17517       0.110818
# 17518       0.105541
# 17519       0.108179
#
# [17520 rows x 11 columns]

# %% [markdown]
# # Outlier Detection

# %%
# %matplotlib inline

plot1=plt.figure(1)
sns.boxplot(y=normalized_alc['NO (µg/m³N)'], whis =10)

plot2=plt.figure(2)
sns.boxplot(y=normalized_alc['NO2 (µg/m³N)'], whis = 10)

plot3=plt.figure(3)
sns.boxplot(y=normalized_alc['SO2 (µg/m³N)'], whis = 10)

plot4=plt.figure(4)
sns.boxplot(y=normalized_alc['O3 (µg/m³N)'], whis = 10)

plot5=plt.figure(5)
sns.boxplot(y=normalized_alc['NOX (µg/m³N)'], whis = 10)

plot6=plt.figure(6)
sns.boxplot(y=normalized_alc['HR (% H.R.)'], whis = 10)

plot7=plt.figure(7)
sns.boxplot(y=normalized_alc['DD (grados)'], whis = 10)

plot8=plt.figure(8)
sns.boxplot(y=normalized_alc['RS (W/m³)'], whis = 10)

plot9=plt.figure(9)
sns.boxplot(y=normalized_alc['PM10 (µg/m³N)'], whis = 10)

plot10=plt.figure(10)
sns.boxplot(y=normalized_alc['TMP (ºC)'], whis = 10)

plot11=plt.figure(11)
sns.boxplot(y=normalized_alc['VV (m/s)'], whis = 10)
# Out:
# <AxesSubplot:ylabel='VV (m/s)'>

# %%
normalized_alc['SO2 (µg/m³N)'] = normalized_alc['SO2 (µg/m³N)'].where(normalized_alc['SO2 (µg/m³N)']<0.6)
normalized_alc['PM10 (µg/m³N)'] = normalized_alc['PM10 (µg/m³N)'].where(normalized_alc['PM10 (µg/m³N)']<0.5)

# %% [markdown]
# # Imputing missing values

# %%
normalized_alc['Date'] = d[:-1]
normalized_alc['Date'] = pd.to_datetime(normalized_alc['Date'], format='%d-%m-%Y')
normalized_alc['Month'] = d[:-1].strftime("%m")
normalized_alc['Hour'] = d[:-1].strftime("%H")
normalized_alc = normalized_alc.set_index('Date')
normalized_alc
# Out:
#                      NO (µg/m³N)  NO2 (µg/m³N)  SO2 (µg/m³N)  O3 (µg/m³N)  \
# Date
# 2018-01-01 00:00:00     0.006329      0.066667      0.028571     0.446541
# 2018-01-01 01:00:00     0.006329      0.057143      0.057143     0.509434
# 2018-01-01 02:00:00     0.003165      0.085714      0.057143     0.490566
# 2018-01-01 03:00:00     0.009494      0.066667      0.057143     0.490566
# 2018-01-01 04:00:00     0.006329      0.066667      0.057143     0.465409
# ...                          ...           ...           ...          ...
# 2019-12-31 19:00:00     0.044304      0.447619      0.000000     0.012579
# 2019-12-31 20:00:00     0.120253      0.514286      0.000000     0.006289
# 2019-12-31 21:00:00     0.262658      0.580952      0.028571     0.000000
# 2019-12-31 22:00:00     0.250000      0.523810      0.028571     0.000000
# 2019-12-31 23:00:00     0.139241      0.352381      0.028571     0.000000
#
#                      TMP (ºC)  HR (% H.R.)  NOX (µg/m³N)  DD (grados)  \
# Date
# 2018-01-01 00:00:00  0.404762          NaN      0.019197     0.852778
# 2018-01-01 01:00:00  0.404762          NaN      0.015707     0.825000
# 2018-01-01 02:00:00  0.380952          NaN      0.019197     0.825000
# 2018-01-01 03:00:00  0.357143          NaN      0.019197     0.838889
# 2018-01-01 04:00:00  0.309524          NaN      0.019197     0.430556
# ...                       ...          ...           ...          ...
# 2019-12-31 19:00:00  0.261905     0.744186      0.120419     0.930556
# 2019-12-31 20:00:00  0.238095     0.802326      0.195462     0.783333
# 2019-12-31 21:00:00  0.190476     0.848837      0.328098     0.888889
# 2019-12-31 22:00:00  0.166667     0.872093      0.308901     0.411111
# 2019-12-31 23:00:00  0.166667     0.883721      0.181501     0.905556
#
#                      RS (W/m³)  VV (m/s)  PM10 (µg/m³N) Month Hour
# Date
# 2018-01-01 00:00:00   0.000000      0.40       0.063325    01   00
# 2018-01-01 01:00:00   0.000000      0.60       0.163588    01   01
# 2018-01-01 02:00:00   0.000000      0.30       0.018470    01   02
# 2018-01-01 03:00:00   0.000000      0.20       0.015831    01   03
# 2018-01-01 04:00:00   0.000000      0.00       0.013193    01   04
# ...                        ...       ...            ...   ...  ...
# 2019-12-31 19:00:00   0.001002      0.04       0.102902    12   19
# 2019-12-31 20:00:00   0.000000      0.04       0.129288    12   20
# 2019-12-31 21:00:00   0.001002      0.04       0.110818    12   21
# 2019-12-31 22:00:00   0.000000      0.04       0.105541    12   22
# 2019-12-31 23:00:00   0.000000      0.03       0.108179    12   23
#
# [17520 rows x 13 columns]

# %% [markdown]
# ## Various interpolation methods

# %%
# alcantarilla_linear = alcantarilla.assign(InterpolateLinear=alcantarilla['SO2 (µg/m³N)'].interpolate(method='linear'))
# alcantarilla_time = alcantarilla.assign(InterpolateTime=alcantarilla['SO2 (µg/m³N)'].interpolate(method='time'))
# alcantarilla_quadratic = alcantarilla.assign(InterpolateQuadratic=alcantarilla['SO2 (µg/m³N)'].interpolate(method='quadratic'))
# alcantarilla_cubic = alcantarilla.assign(InterpolateCubic=alcantarilla['SO2 (µg/m³N)'].interpolate(method='cubic'))
# alcantarilla_slinear = alcantarilla.assign(InterpolateSLinear=alcantarilla['SO2 (µg/m³N)'].interpolate(method='slinear'))
# alcantarilla_akima = alcantarilla.assign(InterpolateAkima=alcantarilla['SO2 (µg/m³N)'].interpolate(method='akima'))
# alcantarilla_poly5 = alcantarilla.assign(InterpolatePoly5=alcantarilla['SO2 (µg/m³N)'].interpolate(method='polynomial', order=5)) 
# alcantarilla_poly7 = alcantarilla.assign(InterpolatePoly7=alcantarilla['SO2 (µg/m³N)'].interpolate(method='polynomial', order=7))
# alcantarilla_spline3 = alcantarilla.assign(InterpolateSpline3=alcantarilla['SO2 (µg/m³N)'].interpolate(method='spline', order=3))
# alcantarilla_spline4 = alcantarilla.assign(InterpolateSpline4=alcantarilla['SO2 (µg/m³N)'].interpolate(method='spline', order=4))
# alcantarilla_spline5 = alcantarilla.assign(InterpolateSpline5=alcantarilla['SO2 (µg/m³N)'].interpolate(method='spline', order=5))

# %% [markdown]
# ## kNN imputation

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5) 
After_imputation = imputer.fit_transform(normalized_alc)
alc_knn = pd.DataFrame(After_imputation, columns = ['NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','NOX (µg/m³N)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)','Month','Hour'])
alc_knn
# Out:
#        NO (µg/m³N)  NO2 (µg/m³N)  SO2 (µg/m³N)  O3 (µg/m³N)  TMP (ºC)  \
# 0         0.006329      0.066667      0.028571     0.446541  0.404762
# 1         0.006329      0.057143      0.057143     0.509434  0.404762
# 2         0.003165      0.085714      0.057143     0.490566  0.380952
# 3         0.009494      0.066667      0.057143     0.490566  0.357143
# 4         0.006329      0.066667      0.057143     0.465409  0.309524
# ...            ...           ...           ...          ...       ...
# 17515     0.044304      0.447619      0.000000     0.012579  0.261905
# 17516     0.120253      0.514286      0.000000     0.006289  0.238095
# 17517     0.262658      0.580952      0.028571     0.000000  0.190476
# 17518     0.250000      0.523810      0.028571     0.000000  0.166667
# 17519     0.139241      0.352381      0.028571     0.000000  0.166667
#
#        HR (% H.R.)  NOX (µg/m³N)  DD (grados)  RS (W/m³)  VV (m/s)  \
# 0         0.518605      0.019197     0.852778   0.000000      0.40
# 1         0.379070      0.015707     0.825000   0.000000      0.60
# 2         0.397674      0.019197     0.825000   0.000000      0.30
# 3         0.472093      0.019197     0.838889   0.000000      0.20
# 4         0.583721      0.019197     0.430556   0.000000      0.00
# ...            ...           ...          ...        ...       ...
# 17515     0.744186      0.120419     0.930556   0.001002      0.04
# 17516     0.802326      0.195462     0.783333   0.000000      0.04
# 17517     0.848837      0.328098     0.888889   0.001002      0.04
# 17518     0.872093      0.308901     0.411111   0.000000      0.04
# 17519     0.883721      0.181501     0.905556   0.000000      0.03
#
#        PM10 (µg/m³N)  Month  Hour
# 0           0.063325    1.0   0.0
# 1           0.163588    1.0   1.0
# 2           0.018470    1.0   2.0
# 3           0.015831    1.0   3.0
# 4           0.013193    1.0   4.0
# ...              ...    ...   ...
# 17515       0.102902   12.0  19.0
# 17516       0.129288   12.0  20.0
# 17517       0.110818   12.0  21.0
# 17518       0.105541   12.0  22.0
# 17519       0.108179   12.0  23.0
#
# [17520 rows x 13 columns]

# %%
denormalized_alc=(alc_knn*(alc.max()-alc.min()))+alc.min()
denormalized_alc['Date'] = d[:-1]
denormalized_alc['Date'] = pd.to_datetime(denormalized_alc['Date'], format='%d-%m-%Y')
in_array = np.linspace(0, np.pi, 17520)
out_array = np.sin(in_array)
denormalized_alc['Month'] = 12*out_array
denormalized_alc['Hour'] = d[:-1].strftime("%H")
denormalized_alc.to_csv('alc.csv',index=False)
denormalized_alc
# Out:
#        DD (grados)  HR (% H.R.) Hour         Month  NO (µg/m³N)  NO2 (µg/m³N)  \
# 0            307.0         56.6   00  0.000000e+00          3.0           9.0
# 1            297.0         44.6   01  2.151899e-03          3.0           8.0
# 2            297.0         46.2   02  4.303797e-03          2.0          11.0
# 3            302.0         52.6   03  6.455696e-03          4.0           9.0
# 4            155.0         62.2   04  8.607594e-03          3.0           9.0
# ...            ...          ...  ...           ...          ...           ...
# 17515        335.0         76.0   19  8.607594e-03         15.0          49.0
# 17516        282.0         81.0   20  6.455696e-03         39.0          56.0
# 17517        320.0         85.0   21  4.303797e-03         84.0          63.0
# 17518        148.0         87.0   22  2.151899e-03         80.0          57.0
# 17519        326.0         88.0   23  1.469576e-15         45.0          39.0
#
#        NOX (µg/m³N)  O3 (µg/m³N)  PM10 (µg/m³N)  RS (W/m³)  SO2 (µg/m³N)  \
# 0              14.0         73.0           25.0        1.0           2.0
# 1              12.0         83.0           63.0        1.0           3.0
# 2              14.0         80.0            8.0        1.0           3.0
# 3              14.0         80.0            7.0        1.0           3.0
# 4              14.0         76.0            6.0        1.0           3.0
# ...             ...          ...            ...        ...           ...
# 17515          72.0          4.0           40.0        2.0           1.0
# 17516         115.0          3.0           50.0        1.0           1.0
# 17517         191.0          2.0           43.0        2.0           2.0
# 17518         180.0          2.0           41.0        1.0           2.0
# 17519         107.0          2.0           42.0        1.0           2.0
#
#        TMP (ºC)  VV (m/s)                Date
# 0          17.0       4.0 2018-01-01 00:00:00
# 1          17.0       6.0 2018-01-01 01:00:00
# 2          16.0       3.0 2018-01-01 02:00:00
# 3          15.0       2.0 2018-01-01 03:00:00
# 4          13.0       0.0 2018-01-01 04:00:00
# ...         ...       ...                 ...
# 17515      11.0       0.4 2019-12-31 19:00:00
# 17516      10.0       0.4 2019-12-31 20:00:00
# 17517       8.0       0.4 2019-12-31 21:00:00
# 17518       7.0       0.4 2019-12-31 22:00:00
# 17519       7.0       0.3 2019-12-31 23:00:00
#
# [17520 rows x 14 columns]

# %%
fig, axs = plt.subplots(4, 3)

alc_knn['Date'] = d[:-1]

axs[0, 0].plot(alc_knn['Date'],alc_knn['NO (µg/m³N)'])
axs[0, 0].set_title('NO (µg/m³N)')

axs[0, 1].plot(alc_knn['Date'],alc_knn['NO2 (µg/m³N)'], 'tab:orange')
axs[0, 1].set_title('NO2 (µg/m³N)')

axs[0, 2].plot(alc_knn['Date'],alc_knn['SO2 (µg/m³N)'], 'tab:green')
axs[0, 2].set_title('SO2 (µg/m³N)')

axs[1, 0].plot(alc_knn['Date'],alc_knn['O3 (µg/m³N)'], 'tab:red')
axs[1, 0].set_title('O3 (µg/m³N)')

axs[1, 1].plot(alc_knn['Date'],alc_knn['NOX (µg/m³N)'], 'tab:purple')
axs[1, 1].set_title('NOX (µg/m³N)')

axs[1, 2].plot(alc_knn['Date'],alc_knn['HR (% H.R.)'])
axs[1, 2].set_title('HR (% H.R.)')

axs[2, 0].plot(alc_knn['Date'],alc_knn['DD (grados)'])
axs[2, 0].set_title('DD (grados)')

axs[2, 1].plot(alc_knn['Date'],alc_knn['RS (W/m³)'], 'tab:orange')
axs[2, 1].set_title('RS (W/m³)')

axs[2, 2].plot(alc_knn['Date'],alc_knn['PM10 (µg/m³N)'], 'tab:green')
axs[2, 2].set_title('PM10 (µg/m³N)')

axs[3, 0].plot(alc_knn['Date'],alc_knn['TMP (ºC)'], 'tab:green')
axs[3, 0].set_title('TMP (ºC)')

axs[3, 1].plot(alc_knn['Date'],alc_knn['VV (m/s)'], 'tab:purple')
axs[3, 1].set_title('VV (m/s)')

for i in [0,1,2,3]:
    for j in [0,1,2]:
        axs[i, j].tick_params(axis='x',which='both', bottom=False, top=False, labelbottom=False)

# %% [markdown]
# ### Testing kNN imputation on sample dataset

# %%
test = pd.read_csv('test.csv')
test = test.set_index('Date')
imputer = KNNImputer(n_neighbors=5) 
After_imputation = imputer.fit_transform(test)
df = pd.DataFrame(After_imputation, columns = ['NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','NOX (µg/m³N)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)','Ref'])
df
# Out:
#        NO (µg/m³N)  NO2 (µg/m³N)  SO2 (µg/m³N)  O3 (µg/m³N)  TMP (ºC)  \
# 0              2.0           4.0           5.0         86.0      17.0
# 1              2.0           8.0           4.0         82.0      19.0
# 2              2.0           6.0           4.0         81.0      21.0
# 3              2.0           5.0           4.0         80.0      22.0
# 4              1.0           4.0           4.0         81.0      24.0
# ...            ...           ...           ...          ...       ...
# 10813         15.0          49.0           1.0          4.0      11.0
# 10814         39.0          56.0           1.0          3.0      10.0
# 10815         84.0          63.0           2.0          2.0       8.0
# 10816         80.0          57.0           2.0          2.0       7.0
# 10817         45.0          39.0           2.0          2.0       7.0
#
#        HR (% H.R.)  NOX (µg/m³N)  DD (grados)  RS (W/m³)  VV (m/s)  \
# 0             35.0           6.0        308.0      739.0       3.0
# 1             33.0          11.0        304.0      611.0       2.0
# 2             32.0           8.0        304.0      739.0       2.0
# 3             30.0           8.0        292.0      818.0       2.0
# 4             28.0           6.0         14.0      827.0       2.0
# ...            ...           ...          ...        ...       ...
# 10813         76.0          72.0        335.0        2.0       0.4
# 10814         81.0         115.0        282.0        1.0       0.4
# 10815         85.0         191.0        320.0        2.0       0.4
# 10816         87.0         180.0        148.0        1.0       0.4
# 10817         88.0         107.0        326.0        1.0       0.3
#
#        PM10 (µg/m³N)  Ref
# 0                4.0  5.0
# 1                9.0  4.0
# 2                6.0  4.0
# 3                6.0  4.0
# 4                5.0  4.0
# ...              ...  ...
# 10813           40.0  1.0
# 10814           50.0  1.0
# 10815           43.0  2.0
# 10816           41.0  2.0
# 10817           42.0  2.0
#
# [10818 rows x 12 columns]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10818 entries, 2018-03-26 13:00:00 to 2019-12-31 23:00:00
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   NO (µg/m³N)    10818 non-null  int64
#  1   NO2 (µg/m³N)   10643 non-null  float64
#  2   SO2 (µg/m³N)   9389 non-null   float64
#  3   O3 (µg/m³N)    10818 non-null  int64
#  4   TMP (ºC)       10818 non-null  int64
#  5   HR (% H.R.)    10818 non-null  int64
#  6   NOX (µg/m³N)   10818 non-null  int64
#  7   DD (grados)    10818 non-null  int64
#  8   RS (W/m³)      10818 non-null  int64
#  9   VV (m/s)       10818 non-null  float64
#  10  PM10 (µg/m³N)  10818 non-null  int64
#  11  Ref            10818 non-null  int64
# dtypes: float64(3), int64(9)
# memory usage: 1.1+ MB

# %%
df.mean()
# Out:
# NO (µg/m³N)        9.926419
# NO2 (µg/m³N)      22.351155
# SO2 (µg/m³N)       3.858273
# O3 (µg/m³N)       52.207802
# TMP (ºC)          19.032723
# HR (% H.R.)       61.108708
# NOX (µg/m³N)      37.493807
# DD (grados)      206.942133
# RS (W/m³)        184.198650
# VV (m/s)           1.356184
# PM10 (µg/m³N)     22.144389
# Ref                3.939545
# dtype: float64

# %%
from sklearn.metrics import mean_squared_error
rms = mean_squared_error(df['SO2 (µg/m³N)'], df['Ref'])
rms
# Out:
# 0.20825291181364394

# %%
(df['SO2 (µg/m³N)']-df['Ref']).where(df['SO2 (µg/m³N)']-df['Ref']!=0).dropna().reset_index().drop('index',1)
# Out:
#         0
# 0    -1.8
# 1    -2.0
# 2    -0.2
# 3    -0.8
# 4    -0.4
# ...   ...
# 1258  0.6
# 1259  0.6
# 1260 -0.4
# 1261  0.6
# 1262 -1.0
#
# [1263 rows x 1 columns]

# %% [markdown]
# # Feature Selection

# %%
corr = alc_knn.corr()
plt.figure(figsize=(16, 6))
sns.heatmap(corr,vmin=-1, vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %%
#Correlation with output variable
for i in (corr.columns):
    cor_target = abs(corr[i])
    corr[i] = cor_target[cor_target<0.6]    
corr
# Out:
#                NO (µg/m³N)  NO2 (µg/m³N)  SO2 (µg/m³N)  O3 (µg/m³N)  TMP (ºC)  \
# NO (µg/m³N)            NaN           NaN      0.277982     0.455251  0.349738
# NO2 (µg/m³N)           NaN           NaN      0.104459          NaN  0.509300
# SO2 (µg/m³N)      0.277982      0.104459           NaN     0.139144  0.208326
# O3 (µg/m³N)       0.455251           NaN      0.139144          NaN       NaN
# TMP (ºC)          0.349738      0.509300      0.208326          NaN       NaN
# HR (% H.R.)       0.245265      0.362747      0.072489          NaN  0.502564
# NOX (µg/m³N)           NaN           NaN      0.236934          NaN  0.447709
# DD (grados)       0.084774      0.237385      0.174406     0.366111  0.355081
# RS (W/m³)         0.142958      0.401258      0.194522          NaN  0.548657
# VV (m/s)          0.221068      0.391237      0.078885     0.463639  0.173147
# PM10 (µg/m³N)     0.312466      0.284039      0.254851     0.070772  0.276829
# Month             0.050925      0.055764      0.121196     0.159637  0.220415
# Hour              0.035306      0.082330      0.058082     0.406988  0.323829
#
#                HR (% H.R.)  NOX (µg/m³N)  DD (grados)  RS (W/m³)  VV (m/s)  \
# NO (µg/m³N)       0.245265           NaN     0.084774   0.142958  0.221068
# NO2 (µg/m³N)      0.362747           NaN     0.237385   0.401258  0.391237
# SO2 (µg/m³N)      0.072489      0.236934     0.174406   0.194522  0.078885
# O3 (µg/m³N)            NaN           NaN     0.366111        NaN  0.463639
# TMP (ºC)          0.502564      0.447709     0.355081   0.548657  0.173147
# HR (% H.R.)            NaN      0.316648     0.134872        NaN  0.489431
# NOX (µg/m³N)      0.316648           NaN     0.153728   0.259919  0.310764
# DD (grados)       0.134872      0.153728          NaN   0.257779  0.158585
# RS (W/m³)              NaN      0.259919     0.257779        NaN  0.277497
# VV (m/s)          0.489431      0.310764     0.158585   0.277497       NaN
# PM10 (µg/m³N)     0.062269      0.332817     0.176459   0.003695  0.181613
# Month             0.189826      0.014100     0.037329   0.047263  0.067790
# Hour              0.441747      0.057475     0.230551   0.301857  0.264579
#
#                PM10 (µg/m³N)         Month          Hour
# NO (µg/m³N)         0.312466  5.092476e-02  3.530593e-02
# NO2 (µg/m³N)        0.284039  5.576364e-02  8.232978e-02
# SO2 (µg/m³N)        0.254851  1.211964e-01  5.808154e-02
# O3 (µg/m³N)         0.070772  1.596369e-01  4.069876e-01
# TMP (ºC)            0.276829  2.204147e-01  3.238291e-01
# HR (% H.R.)         0.062269  1.898255e-01  4.417472e-01
# NOX (µg/m³N)        0.332817  1.409970e-02  5.747473e-02
# DD (grados)         0.176459  3.732885e-02  2.305510e-01
# RS (W/m³)           0.003695  4.726305e-02  3.018569e-01
# VV (m/s)            0.181613  6.779050e-02  2.645792e-01
# PM10 (µg/m³N)            NaN  1.315258e-01  1.263959e-01
# Month               0.131526           NaN  2.548916e-19
# Hour                0.126396  2.548916e-19           NaN

# %% [markdown]
# # Time Series features

# %%
denormalized_alc
# Out:
#        DD (grados)  HR (% H.R.) Hour         Month  NO (µg/m³N)  NO2 (µg/m³N)  \
# 0            307.0         56.6   00  0.000000e+00          3.0           9.0
# 1            297.0         44.6   01  2.151899e-03          3.0           8.0
# 2            297.0         46.2   02  4.303797e-03          2.0          11.0
# 3            302.0         52.6   03  6.455696e-03          4.0           9.0
# 4            155.0         62.2   04  8.607594e-03          3.0           9.0
# ...            ...          ...  ...           ...          ...           ...
# 17515        335.0         76.0   19  8.607594e-03         15.0          49.0
# 17516        282.0         81.0   20  6.455696e-03         39.0          56.0
# 17517        320.0         85.0   21  4.303797e-03         84.0          63.0
# 17518        148.0         87.0   22  2.151899e-03         80.0          57.0
# 17519        326.0         88.0   23  1.469576e-15         45.0          39.0
#
#        NOX (µg/m³N)  O3 (µg/m³N)  PM10 (µg/m³N)  RS (W/m³)  SO2 (µg/m³N)  \
# 0              14.0         73.0           25.0        1.0           2.0
# 1              12.0         83.0           63.0        1.0           3.0
# 2              14.0         80.0            8.0        1.0           3.0
# 3              14.0         80.0            7.0        1.0           3.0
# 4              14.0         76.0            6.0        1.0           3.0
# ...             ...          ...            ...        ...           ...
# 17515          72.0          4.0           40.0        2.0           1.0
# 17516         115.0          3.0           50.0        1.0           1.0
# 17517         191.0          2.0           43.0        2.0           2.0
# 17518         180.0          2.0           41.0        1.0           2.0
# 17519         107.0          2.0           42.0        1.0           2.0
#
#        TMP (ºC)  VV (m/s)                Date
# 0          17.0       4.0 2018-01-01 00:00:00
# 1          17.0       6.0 2018-01-01 01:00:00
# 2          16.0       3.0 2018-01-01 02:00:00
# 3          15.0       2.0 2018-01-01 03:00:00
# 4          13.0       0.0 2018-01-01 04:00:00
# ...         ...       ...                 ...
# 17515      11.0       0.4 2019-12-31 19:00:00
# 17516      10.0       0.4 2019-12-31 20:00:00
# 17517       8.0       0.4 2019-12-31 21:00:00
# 17518       7.0       0.4 2019-12-31 22:00:00
# 17519       7.0       0.3 2019-12-31 23:00:00
#
# [17520 rows x 14 columns]

# %%
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
series = denormalized_alc['NO (µg/m³N)']
plot_acf(series)
plot_pacf(series)
pyplot.show()

# %%
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
series = denormalized_alc['NO2 (µg/m³N)']
plot_acf(series)
plot_pacf(series)
pyplot.show()

# %%
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
series = denormalized_alc['NOX (µg/m³N)']
plot_acf(series)
plot_pacf(series)
pyplot.show()

# %%
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
series = denormalized_alc['SO2 (µg/m³N)']
plot_acf(series)
plot_pacf(series)
pyplot.show()

# %%
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
series = denormalized_alc['O3 (µg/m³N)']
plot_acf(series)
plot_pacf(series)
pyplot.show()

# %%
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
series = denormalized_alc['PM10 (µg/m³N)']
plot_acf(series)
plot_pacf(series)
pyplot.show()

# %%
from pandas import DataFrame
from pandas import concat
temps = denormalized_alc
shifted = temps.shift(1)
window = shifted.rolling(window=24)
means = window.mean()
means
# Out:
#        DD (grados)  HR (% H.R.)  Hour     Month  NO (µg/m³N)  NO2 (µg/m³N)  \
# 0              NaN          NaN   NaN       NaN          NaN           NaN
# 1              NaN          NaN   NaN       NaN          NaN           NaN
# 2              NaN          NaN   NaN       NaN          NaN           NaN
# 3              NaN          NaN   NaN       NaN          NaN           NaN
# 4              NaN          NaN   NaN       NaN          NaN           NaN
# ...            ...          ...   ...       ...          ...           ...
# 17515   179.250000    77.750000  12.5  0.022595    38.166667     31.416667
# 17516   184.916667    76.500000  13.5  0.020443    34.500000     32.916667
# 17517   202.833333    75.666667  14.5  0.018291    31.333333     34.916667
# 17518   200.916667    75.166667  15.5  0.016139    28.083333     36.666667
# 17519   188.416667    75.000000  16.5  0.013987    30.416667     39.000000
#
#        NOX (µg/m³N)  O3 (µg/m³N)  PM10 (µg/m³N)   RS (W/m³)  SO2 (µg/m³N)  \
# 0               NaN          NaN            NaN         NaN           NaN
# 1               NaN          NaN            NaN         NaN           NaN
# 2               NaN          NaN            NaN         NaN           NaN
# 3               NaN          NaN            NaN         NaN           NaN
# 4               NaN          NaN            NaN         NaN           NaN
# ...             ...          ...            ...         ...           ...
# 17515     89.666667    18.916667      29.000000  146.250000      2.583333
# 17516     85.666667    19.083333      30.750000  146.250000      2.416667
# 17517     82.833333    19.166667      33.083333  146.166667      2.166667
# 17518     79.583333    19.166667      33.666667  145.166667      1.916667
# 17519     85.500000    19.000000      34.333333  136.416667      1.833333
#
#         TMP (ºC)  VV (m/s)
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ...          ...       ...
# 17515   9.416667  0.541667
# 17516  10.000000  0.550000
# 17517  10.500000  0.558333
# 17518  10.833333  0.566667
# 17519  10.916667  0.550000
#
# [17520 rows x 13 columns]

# %%
denormalized_alc['NO_roll_mean'] = means['NO (µg/m³N)']
denormalized_alc['NO2_roll_mean'] = means['NO2 (µg/m³N)']
denormalized_alc['NOX_roll_mean'] = means['NOX (µg/m³N)']
denormalized_alc['PM10_roll_mean'] = means['PM10 (µg/m³N)']
denormalized_alc['O3_roll_mean'] = means['O3 (µg/m³N)']
denormalized_alc
# Out:
#        DD (grados)  HR (% H.R.) Hour         Month  NO (µg/m³N)  NO2 (µg/m³N)  \
# 0            307.0         56.6   00  0.000000e+00          3.0           9.0
# 1            297.0         44.6   01  2.151899e-03          3.0           8.0
# 2            297.0         46.2   02  4.303797e-03          2.0          11.0
# 3            302.0         52.6   03  6.455696e-03          4.0           9.0
# 4            155.0         62.2   04  8.607594e-03          3.0           9.0
# ...            ...          ...  ...           ...          ...           ...
# 17515        335.0         76.0   19  8.607594e-03         15.0          49.0
# 17516        282.0         81.0   20  6.455696e-03         39.0          56.0
# 17517        320.0         85.0   21  4.303797e-03         84.0          63.0
# 17518        148.0         87.0   22  2.151899e-03         80.0          57.0
# 17519        326.0         88.0   23  1.469576e-15         45.0          39.0
#
#        NOX (µg/m³N)  O3 (µg/m³N)  PM10 (µg/m³N)  RS (W/m³)  SO2 (µg/m³N)  \
# 0              14.0         73.0           25.0        1.0           2.0
# 1              12.0         83.0           63.0        1.0           3.0
# 2              14.0         80.0            8.0        1.0           3.0
# 3              14.0         80.0            7.0        1.0           3.0
# 4              14.0         76.0            6.0        1.0           3.0
# ...             ...          ...            ...        ...           ...
# 17515          72.0          4.0           40.0        2.0           1.0
# 17516         115.0          3.0           50.0        1.0           1.0
# 17517         191.0          2.0           43.0        2.0           2.0
# 17518         180.0          2.0           41.0        1.0           2.0
# 17519         107.0          2.0           42.0        1.0           2.0
#
#        TMP (ºC)  VV (m/s)                Date  NO_roll_mean  NO2_roll_mean  \
# 0          17.0       4.0 2018-01-01 00:00:00           NaN            NaN
# 1          17.0       6.0 2018-01-01 01:00:00           NaN            NaN
# 2          16.0       3.0 2018-01-01 02:00:00           NaN            NaN
# 3          15.0       2.0 2018-01-01 03:00:00           NaN            NaN
# 4          13.0       0.0 2018-01-01 04:00:00           NaN            NaN
# ...         ...       ...                 ...           ...            ...
# 17515      11.0       0.4 2019-12-31 19:00:00     38.166667      31.416667
# 17516      10.0       0.4 2019-12-31 20:00:00     34.500000      32.916667
# 17517       8.0       0.4 2019-12-31 21:00:00     31.333333      34.916667
# 17518       7.0       0.4 2019-12-31 22:00:00     28.083333      36.666667
# 17519       7.0       0.3 2019-12-31 23:00:00     30.416667      39.000000
#
#        NOX_roll_mean  PM10_roll_mean  O3_roll_mean
# 0                NaN             NaN           NaN
# 1                NaN             NaN           NaN
# 2                NaN             NaN           NaN
# 3                NaN             NaN           NaN
# 4                NaN             NaN           NaN
# ...              ...             ...           ...
# 17515      89.666667       29.000000     18.916667
# 17516      85.666667       30.750000     19.083333
# 17517      82.833333       33.083333     19.166667
# 17518      79.583333       33.666667     19.166667
# 17519      85.500000       34.333333     19.000000
#
# [17520 rows x 19 columns]

# %%
corr = denormalized_alc.corr()
plt.figure(figsize=(16, 6))
sns.heatmap(corr,vmin=-1, vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %%
from pandas import DataFrame
from pandas import concat
temps = denormalized_alc
shifted1 = temps.shift(1)
shifted2 = temps.shift(2)
shifted1
# Out:
#        DD (grados)  HR (% H.R.) Hour     Month  NO (µg/m³N)  NO2 (µg/m³N)  \
# 0              NaN          NaN  NaN       NaN          NaN           NaN
# 1            307.0         56.6   00  0.000000          3.0           9.0
# 2            297.0         44.6   01  0.002152          3.0           8.0
# 3            297.0         46.2   02  0.004304          2.0          11.0
# 4            302.0         52.6   03  0.006456          4.0           9.0
# ...            ...          ...  ...       ...          ...           ...
# 17515         68.0         66.0   18  0.010759          3.0          31.0
# 17516        335.0         76.0   19  0.008608         15.0          49.0
# 17517        282.0         81.0   20  0.006456         39.0          56.0
# 17518        320.0         85.0   21  0.004304         84.0          63.0
# 17519        148.0         87.0   22  0.002152         80.0          57.0
#
#        NOX (µg/m³N)  O3 (µg/m³N)  PM10 (µg/m³N)  RS (W/m³)  SO2 (µg/m³N)  \
# 0               NaN          NaN            NaN        NaN           NaN
# 1              14.0         73.0           25.0        1.0           2.0
# 2              12.0         83.0           63.0        1.0           3.0
# 3              14.0         80.0            8.0        1.0           3.0
# 4              14.0         80.0            7.0        1.0           3.0
# ...             ...          ...            ...        ...           ...
# 17515          36.0         31.0           32.0       41.0           1.0
# 17516          72.0          4.0           40.0        2.0           1.0
# 17517         115.0          3.0           50.0        1.0           1.0
# 17518         191.0          2.0           43.0        2.0           2.0
# 17519         180.0          2.0           41.0        1.0           2.0
#
#        TMP (ºC)  VV (m/s)                Date  NO_roll_mean  NO2_roll_mean  \
# 0           NaN       NaN                 NaT           NaN            NaN
# 1          17.0       4.0 2018-01-01 00:00:00           NaN            NaN
# 2          17.0       6.0 2018-01-01 01:00:00           NaN            NaN
# 3          16.0       3.0 2018-01-01 02:00:00           NaN            NaN
# 4          15.0       2.0 2018-01-01 03:00:00           NaN            NaN
# ...         ...       ...                 ...           ...            ...
# 17515      14.0       0.5 2019-12-31 18:00:00     40.000000      30.833333
# 17516      11.0       0.4 2019-12-31 19:00:00     38.166667      31.416667
# 17517      10.0       0.4 2019-12-31 20:00:00     34.500000      32.916667
# 17518       8.0       0.4 2019-12-31 21:00:00     31.333333      34.916667
# 17519       7.0       0.4 2019-12-31 22:00:00     28.083333      36.666667
#
#        NOX_roll_mean  PM10_roll_mean  O3_roll_mean
# 0                NaN             NaN           NaN
# 1                NaN             NaN           NaN
# 2                NaN             NaN           NaN
# 3                NaN             NaN           NaN
# 4                NaN             NaN           NaN
# ...              ...             ...           ...
# 17515      91.833333       27.416667     16.500000
# 17516      89.666667       29.000000     18.916667
# 17517      85.666667       30.750000     19.083333
# 17518      82.833333       33.083333     19.166667
# 17519      79.583333       33.666667     19.166667
#
# [17520 rows x 19 columns]

# %%
denormalized_alc['NO_lag1'] = shifted1['NO (µg/m³N)']
denormalized_alc['NO2_lag1'] = shifted1['NO2 (µg/m³N)']
denormalized_alc['NOX_lag1'] = shifted1['NOX (µg/m³N)']
denormalized_alc['PM10_lag1'] = shifted1['PM10 (µg/m³N)']
denormalized_alc['O3_lag1'] = shifted1['O3 (µg/m³N)']
denormalized_alc['NO_lag2'] = shifted2['NO (µg/m³N)']
denormalized_alc['NO2_lag2'] = shifted2['NO2 (µg/m³N)']
denormalized_alc['NOX_lag2'] = shifted2['NOX (µg/m³N)']
denormalized_alc['PM10_lag2'] = shifted2['PM10 (µg/m³N)']
denormalized_alc['O3_lag2'] = shifted2['O3 (µg/m³N)']
denormalized_alc = denormalized_alc.dropna()
denormalized_alc.to_csv('alc.csv',index=False)
denormalized_alc
# Out:
# <ipython-input-111-5fa09e9fb6bf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   denormalized_alc['NO_lag1'] = shifted1['NO (µg/m³N)']
# <ipython-input-111-5fa09e9fb6bf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   denormalized_alc['NO2_lag1'] = shifted1['NO2 (µg/m³N)']
# <ipython-input-111-5fa09e9fb6bf>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   denormalized_alc['NOX_lag1'] = shifted1['NOX (µg/m³N)']
# <ipython-input-111-5fa09e9fb6bf>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   denormalized_alc['PM10_lag1'] = shifted1['PM10 (µg/m³N)']
# <ipython-input-111-5fa09e9fb6bf>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   denormalized_alc['O3_lag1'] = shifted1['O3 (µg/m³N)']
# <ipython-input-111-5fa09e9fb6bf>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   denormalized_alc['NO_lag2'] = shifted2['NO (µg/m³N)']
# <ipython-input-111-5fa09e9fb6bf>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   denormalized_alc['NO2_lag2'] = shifted2['NO2 (µg/m³N)']
# <ipython-input-111-5fa09e9fb6bf>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   denormalized_alc['NOX_lag2'] = shifted2['NOX (µg/m³N)']
# <ipython-input-111-5fa09e9fb6bf>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   denormalized_alc['PM10_lag2'] = shifted2['PM10 (µg/m³N)']
# <ipython-input-111-5fa09e9fb6bf>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   denormalized_alc['O3_lag2'] = shifted2['O3 (µg/m³N)']
#        DD (grados)  HR (% H.R.) Hour         Month  NO (µg/m³N)  NO2 (µg/m³N)  \
# 12           265.0         39.0   12  2.582276e-02          4.0          10.0
# 13           248.0         36.8   13  2.797466e-02          3.0          10.0
# 14           128.0         39.4   14  3.012655e-02          4.0          11.0
# 15           185.0         33.6   15  3.227844e-02          4.0           8.0
# 16           232.0         33.6   16  3.443033e-02          2.0           9.0
# ...            ...          ...  ...           ...          ...           ...
# 17515        335.0         76.0   19  8.607594e-03         15.0          49.0
# 17516        282.0         81.0   20  6.455696e-03         39.0          56.0
# 17517        320.0         85.0   21  4.303797e-03         84.0          63.0
# 17518        148.0         87.0   22  2.151899e-03         80.0          57.0
# 17519        326.0         88.0   23  1.469576e-15         45.0          39.0
#
#        NOX (µg/m³N)  O3 (µg/m³N)  PM10 (µg/m³N)  RS (W/m³)  ...  NO_lag1  \
# 12             15.0         71.0            5.0      350.0  ...      5.0
# 13             14.0         77.0            7.0      474.0  ...      4.0
# 14             17.0         77.0            8.0      482.0  ...      3.0
# 15             14.0         82.0            4.0      455.0  ...      4.0
# 16             12.0         87.0            9.0      368.0  ...      4.0
# ...             ...          ...            ...        ...  ...      ...
# 17515          72.0          4.0           40.0        2.0  ...      3.0
# 17516         115.0          3.0           50.0        1.0  ...     15.0
# 17517         191.0          2.0           43.0        2.0  ...     39.0
# 17518         180.0          2.0           41.0        1.0  ...     84.0
# 17519         107.0          2.0           42.0        1.0  ...     80.0
#
#        NO2_lag1  NOX_lag1 PM10_lag1  O3_lag1  NO_lag2  NO2_lag2  NOX_lag2  \
# 12         11.0      18.0       7.0     69.0      5.0      20.0      27.0
# 13         10.0      15.0       5.0     71.0      5.0      11.0      18.0
# 14         10.0      14.0       7.0     77.0      4.0      10.0      15.0
# 15         11.0      17.0       8.0     77.0      3.0      10.0      14.0
# 16          8.0      14.0       4.0     82.0      4.0      11.0      17.0
# ...         ...       ...       ...      ...      ...       ...       ...
# 17515      31.0      36.0      32.0     31.0      3.0      18.0      22.0
# 17516      49.0      72.0      40.0      4.0      3.0      31.0      36.0
# 17517      56.0     115.0      50.0      3.0     15.0      49.0      72.0
# 17518      63.0     191.0      43.0      2.0     39.0      56.0     115.0
# 17519      57.0     180.0      41.0      2.0     84.0      63.0     191.0
#
#        PM10_lag2  O3_lag2
# 12          11.0     46.0
# 13           7.0     69.0
# 14           5.0     71.0
# 15           7.0     77.0
# 16           8.0     77.0
# ...          ...      ...
# 17515       26.0     49.0
# 17516       32.0     31.0
# 17517       40.0      4.0
# 17518       50.0      3.0
# 17519       43.0      2.0
#
# [17508 rows x 29 columns]

# %%
denormalized_alc.columns
# Out:
# Index(['DD (grados)', 'HR (% H.R.)', 'Hour', 'Month', 'NO (µg/m³N)',
#        'NO2 (µg/m³N)', 'NOX (µg/m³N)', 'O3 (µg/m³N)', 'PM10 (µg/m³N)',
#        'RS (W/m³)', 'SO2 (µg/m³N)', 'TMP (ºC)', 'VV (m/s)', 'Date',
#        'NO_roll_mean', 'NO2_roll_mean', 'NOX_roll_mean', 'PM10_roll_mean',
#        'O3_roll_mean', 'NO_lag1', 'NO2_lag1', 'NOX_lag1', 'PM10_lag1',
#        'O3_lag1', 'NO_lag2', 'NO2_lag2', 'NOX_lag2', 'PM10_lag2', 'O3_lag2'],
#       dtype='object')
