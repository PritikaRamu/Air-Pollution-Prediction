# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df_18 = pd.read_csv('Alcantarillahorarias2018.csv', header=1)
df_18= df_18.drop(['PRB (mb)','C6H6 (µg/m³N)','C7H8 (µg/m³N)','XIL (µg/m³N)'],axis =1)
df_18
# Out:
#              Fecha  NO (µg/m³N)  NO2 (µg/m³N)  SO2 (µg/m³N)  O3 (µg/m³N)  \
# 0      1 ene. 2018          3.0           9.0           2.0         73.0
# 1      1 ene. 2018          3.0           8.0           3.0         83.0
# 2      1 ene. 2018          2.0          11.0           3.0         80.0
# 3      1 ene. 2018          4.0           9.0           3.0         80.0
# 4      1 ene. 2018          3.0           9.0           3.0         76.0
# ...            ...          ...           ...           ...          ...
# 8755  31 dic. 2018         43.0          78.0           4.0          2.0
# 8756  31 dic. 2018         42.0          74.0           4.0          2.0
# 8757  31 dic. 2018         57.0          70.0           5.0          2.0
# 8758  31 dic. 2018         68.0          70.0           6.0          2.0
# 8759  31 dic. 2018         33.0          50.0           4.0          2.0
#
#       TMP (ºC)  HR (% H.R.)  NOX (µg/m³N)  DD (grados)  RS (W/m³)  VV (m/s)  \
# ...

# %%
plt.figure(figsize=(16, 6))
sns.heatmap(df_18.corr(method='pearson'), vmin=-1, vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %%
#plt.scatter(df['Fecha'],df['NO (µg/m³N)'])

# %%
#plt.scatter(df['Fecha'],df['NO2 (µg/m³N)'])

# %%
#plt.scatter(df['Fecha'],df['SO2 (µg/m³N)'])

# %%
#plt.scatter(df['Fecha'],df['O3 (µg/m³N)'])

# %%
fig, axs = plt.subplots(4, 3)

axs[0, 0].plot(df['Fecha'],df['NO (µg/m³N)'])
axs[0, 0].set_title('NO (µg/m³N)')

axs[0, 1].plot(df['Fecha'],df['NO2 (µg/m³N)'], 'tab:orange')
axs[0, 1].set_title('NO2 (µg/m³N)')

axs[0, 2].plot(df['Fecha'],df['SO2 (µg/m³N)'], 'tab:green')
axs[0, 2].set_title('SO2 (µg/m³N)')

axs[1, 0].plot(df['Fecha'],df['O3 (µg/m³N)'], 'tab:red')
axs[1, 0].set_title('O3 (µg/m³N)')

axs[1, 1].plot(df['Fecha'],df['NOX (µg/m³N)'], 'tab:purple')
axs[1, 1].set_title('NOX (µg/m³N)')

axs[1, 2].plot(df['Fecha'],df['HR (% H.R.)'])
axs[1, 2].set_title('HR (% H.R.)')

axs[2, 0].plot(df['Fecha'],df['DD (grados)'])
axs[2, 0].set_title('DD (grados)')

axs[2, 1].plot(df['Fecha'],df['RS (W/m³)'], 'tab:orange')
axs[2, 1].set_title('RS (W/m³)')

axs[2, 2].plot(df['Fecha'],df['PM10 (µg/m³N)'], 'tab:green')
axs[2, 2].set_title('PM10 (µg/m³N)')

axs[3, 0].plot(df['Fecha'],df['TMP (ºC)'], 'tab:green')
axs[3, 0].set_title('TMP (ºC)')

axs[3, 1].plot(df['Fecha'],df['VV (m/s)'], 'tab:green')
axs[3, 1].set_title('VV (m/s)')

for i in [0,1,2,3]:
    for j in [0,1,2]:
        axs[i, j].tick_params(axis='x',which='both', bottom=False, top=False, labelbottom=False)

# %%
df_19 = pd.read_csv('Alcantarillahorarias2019.csv', header=1)
df_19 = df_19.drop(['PRB (mb)','C6H6 (µg/m³N)','C7H8 (µg/m³N)','XIL (µg/m³N)'],axis =1)
df_19
# Out:
#              Fecha  NO (µg/m³N)  NO2 (µg/m³N)  SO2 (µg/m³N)  O3 (µg/m³N)  \
# 0      1 ene. 2019         27.0          44.0           4.0          5.0
# 1      1 ene. 2019         33.0          40.0           4.0          4.0
# 2      1 ene. 2019         65.0          45.0           5.0          5.0
# 3      1 ene. 2019         77.0          45.0           6.0          3.0
# 4      1 ene. 2019         52.0          38.0           5.0          3.0
# ...            ...          ...           ...           ...          ...
# 8755  31 dic. 2019         15.0          49.0           1.0          4.0
# 8756  31 dic. 2019         39.0          56.0           1.0          3.0
# 8757  31 dic. 2019         84.0          63.0           2.0          2.0
# 8758  31 dic. 2019         80.0          57.0           2.0          2.0
# 8759  31 dic. 2019         45.0          39.0           2.0          2.0
#
#       TMP (ºC)  HR (% H.R.)  NOX (µg/m³N)  DD (grados)  RS (W/m³)  VV (m/s)  \
# ...

# %%
plt.figure(figsize=(16, 6))
sns.heatmap(df_19.corr(method='pearson'), vmin=-1, vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %%
fig, axs = plt.subplots(3, 3)

axs[0, 0].plot(df_19['Fecha'],df_19['NO (µg/m³N)'])
axs[0, 0].set_title('NO (µg/m³N)')

axs[0, 1].plot(df_19['Fecha'],df_19['NO2 (µg/m³N)'], 'tab:orange')
axs[0, 1].set_title('NO2 (µg/m³N)')

axs[0, 2].plot(df_19['Fecha'],df_19['SO2 (µg/m³N)'], 'tab:green')
axs[0, 2].set_title('SO2 (µg/m³N)')

axs[1, 0].plot(df_19['Fecha'],df_19['O3 (µg/m³N)'], 'tab:red')
axs[1, 0].set_title('O3 (µg/m³N)')

axs[1, 1].plot(df_19['Fecha'],df_19['NOX (µg/m³N)'], 'tab:purple')
axs[1, 1].set_title('NOX (µg/m³N)')

axs[1, 2].plot(df_19['Fecha'],df_19['C6H6 (µg/m³N)'])
axs[1, 2].set_title('C6H6 (µg/m³N)')

axs[2, 0].plot(df_19['Fecha'],df_19['C7H8 (µg/m³N)'])
axs[2, 0].set_title('C7H8 (µg/m³N)')

axs[2, 1].plot(df_19['Fecha'],df_19['XIL (µg/m³N)'], 'tab:orange')
axs[2, 1].set_title('XIL (µg/m³N)')

axs[2, 2].plot(df_19['Fecha'],df_19['PM10 (µg/m³N)'], 'tab:green')
axs[2, 2].set_title('PM10 (µg/m³N)')

for i in [0,1,2]:
    for j in [0,1,2]:
        axs[i, j].tick_params(axis='x',which='both', bottom=False, top=False, labelbottom=False)

# %%
fig, axs = plt.subplots(3,3)
axs[0,0].plot(df['Fecha'],df['TMP (ºC)'])
axs[0,0].set_title('2018')
axs[0,1].plot(df_19['Fecha'],df_19['TMP (ºC)'])
axs[0,1].set_title('2019')
# Out:
# Text(0.5, 1.0, '2019')
