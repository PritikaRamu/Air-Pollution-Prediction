# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import math

# %%
df_18 = pd.read_csv('Aljorrahorarias2018.csv', header=1)
df_18= df_18.drop(['PRB (mb)'],axis =1)
df_18.rename(columns = {'Fecha':'Date'}, inplace = True) 
df_18
# Out:
#               Date  NO (µg/m³N)  NO2 (µg/m³N)  SO2 (µg/m³N)  O3 (µg/m³N)  \
# 0      1 ene. 2018          3.0           8.0           7.0         70.0
# 1      1 ene. 2018          4.0           8.0           8.0         66.0
# 2      1 ene. 2018          3.0           7.0          10.0         78.0
# 3      1 ene. 2018          3.0           8.0          11.0         77.0
# 4      1 ene. 2018          3.0          10.0           9.0         74.0
# ...            ...          ...           ...           ...          ...
# 8755  31 dic. 2018         31.0          64.0           9.0         35.0
# 8756  31 dic. 2018         41.0          76.0          10.0          6.0
# 8757  31 dic. 2018          4.0           7.0           9.0         16.0
# 8758  31 dic. 2018         15.0          46.0          11.0         15.0
# 8759  31 dic. 2018          5.0          27.0          14.0         17.0
#
#       TMP (ºC)  HR (% H.R.)  NOX (µg/m³N)  DD (grados)  RS (W/m³)  VV (m/s)  \
# 0         19.0         47.0          13.0        282.0        2.0       1.0
# 1         18.0         49.0          13.0        319.0        2.0       2.0
# 2         17.0         44.0          12.0        329.0        1.0       3.0
# 3         16.0         47.0          13.0        327.0        1.0       1.0
# 4         15.0         51.0          15.0        330.0        1.0       1.0
# ...        ...          ...           ...          ...        ...       ...
# 8755      15.0         52.0         112.0        240.0        4.0       1.0
# 8756      13.0         65.0         139.0        298.0        2.0       1.0
# 8757      10.0         73.0          12.0        296.0        2.0       1.0
# 8758       9.0         80.0          69.0        320.0        3.0       1.0
# 8759       8.0         84.0          34.0        306.0        3.0       1.0
#
#       PM10 (µg/m³N)
# 0              41.0
# 1              62.0
# 2             103.0
# 3              18.0
# 4               5.0
# ...             ...
# 8755           46.0
# 8756           89.0
# 8757           37.0
# 8758           60.0
# 8759           30.0
#
# [8760 rows x 12 columns]

# %%
df_19 = pd.read_csv('Aljorrahorarias2019.csv', header=1)
df_19= df_19.drop(['PRB (mb)','C6H6 (µg/m³N)','C7H8 (µg/m³N)','XIL (µg/m³N)'],axis =1)
df_19.rename(columns = {'Fecha':'Date'}, inplace = True) 
df_19
# Out:
#               Date  NO (µg/m³N)  NO2 (µg/m³N)  SO2 (µg/m³N)  O3 (µg/m³N)  \
# 0      1 ene. 2019          3.0          18.0          14.0         55.0
# 1      1 ene. 2019          4.0          19.0          14.0         57.0
# 2      1 ene. 2019          4.0          20.0          16.0         48.0
# 3      1 ene. 2019          4.0          18.0          14.0         47.0
# 4      1 ene. 2019          4.0          12.0          16.0         55.0
# ...            ...          ...           ...           ...          ...
# 8755  31 dic. 2019          3.0          18.0           7.0         43.0
# 8756  31 dic. 2019          6.0          29.0           9.0         19.0
# 8757  31 dic. 2019         15.0          31.0          11.0          5.0
# 8758  31 dic. 2019          3.0          23.0           8.0          9.0
# 8759  31 dic. 2019          2.0          16.0           6.0         15.0
#
#       TMP (ºC)  HR (% H.R.)  NOX (µg/m³N)  DD (grados)  RS (W/m³)  VV (m/s)  \
# 0         11.0         72.0          23.0        295.0        3.0       1.0
# 1         11.0         61.0          24.0        292.0        2.0       1.0
# 2         10.0         65.0          26.0        299.0        2.0       1.0
# 3          9.0         68.0          23.0        302.0        3.0       1.0
# 4         10.0         64.0          18.0        298.0        3.0       1.0
# ...        ...          ...           ...          ...        ...       ...
# 8755      13.0         87.0          22.0        158.0        2.0       1.0
# 8756      12.0         94.0          38.0        245.0        2.0       1.0
# 8757      11.0         98.0          54.0        317.0        2.0       1.0
# 8758       9.0        100.0          28.0        306.0        3.0       1.0
# 8759       9.0        100.0          18.0        315.0        3.0       1.0
#
#       PM10 (µg/m³N)
# 0              10.0
# 1               8.0
# 2              12.0
# 3               8.0
# 4               5.0
# ...             ...
# 8755           39.0
# 8756           36.0
# 8757           53.0
# 8758           26.0
# 8759           21.0
#
# [8760 rows x 12 columns]

# %%
aljorra = pd.concat([df_18,df_19])
d = pd.date_range(start ='1-1-2018', end ='1-1-2020', freq ='H')
aljorra['Date'] = d[:-1]
aljorra['Month'] = d[:-1].strftime("%m")
aljorra['Hour'] = d[:-1].strftime("%H")
aljorra.to_csv('aljorra.csv',index=False)
aljorra =  aljorra.reset_index()
aljorra = aljorra.drop('index',1)
aljorra
# Out:
#                      Date  NO (µg/m³N)  NO2 (µg/m³N)  SO2 (µg/m³N)  \
# 0     2018-01-01 00:00:00          3.0           8.0           7.0
# 1     2018-01-01 01:00:00          4.0           8.0           8.0
# 2     2018-01-01 02:00:00          3.0           7.0          10.0
# 3     2018-01-01 03:00:00          3.0           8.0          11.0
# 4     2018-01-01 04:00:00          3.0          10.0           9.0
# ...                   ...          ...           ...           ...
# 17515 2019-12-31 19:00:00          3.0          18.0           7.0
# 17516 2019-12-31 20:00:00          6.0          29.0           9.0
# 17517 2019-12-31 21:00:00         15.0          31.0          11.0
# 17518 2019-12-31 22:00:00          3.0          23.0           8.0
# 17519 2019-12-31 23:00:00          2.0          16.0           6.0
#
#        O3 (µg/m³N)  TMP (ºC)  HR (% H.R.)  NOX (µg/m³N)  DD (grados)  \
# 0             70.0      19.0         47.0          13.0        282.0
# 1             66.0      18.0         49.0          13.0        319.0
# 2             78.0      17.0         44.0          12.0        329.0
# 3             77.0      16.0         47.0          13.0        327.0
# 4             74.0      15.0         51.0          15.0        330.0
# ...            ...       ...          ...           ...          ...
# 17515         43.0      13.0         87.0          22.0        158.0
# 17516         19.0      12.0         94.0          38.0        245.0
# 17517          5.0      11.0         98.0          54.0        317.0
# 17518          9.0       9.0        100.0          28.0        306.0
# 17519         15.0       9.0        100.0          18.0        315.0
#
#        RS (W/m³)  VV (m/s)  PM10 (µg/m³N) Month Hour
# 0            2.0       1.0           41.0    01   00
# 1            2.0       2.0           62.0    01   01
# 2            1.0       3.0          103.0    01   02
# 3            1.0       1.0           18.0    01   03
# 4            1.0       1.0            5.0    01   04
# ...          ...       ...            ...   ...  ...
# 17515        2.0       1.0           39.0    12   19
# 17516        2.0       1.0           36.0    12   20
# 17517        2.0       1.0           53.0    12   21
# 17518        3.0       1.0           26.0    12   22
# 17519        3.0       1.0           21.0    12   23
#
# [17520 rows x 14 columns]

# %%
alc = aljorra.drop(columns=['Date','Month','Hour'])
normalized_al=(alc-alc.min())/(alc.max()-alc.min())
normalized_al
# Out:
#        NO (µg/m³N)  NO2 (µg/m³N)  SO2 (µg/m³N)  O3 (µg/m³N)  TMP (ºC)  \
# 0         0.016667      0.072289      0.088608     0.439490  0.428571
# 1         0.025000      0.072289      0.101266     0.414013  0.400000
# 2         0.016667      0.060241      0.126582     0.490446  0.371429
# 3         0.016667      0.072289      0.139241     0.484076  0.342857
# 4         0.016667      0.096386      0.113924     0.464968  0.314286
# ...            ...           ...           ...          ...       ...
# 17515     0.016667      0.192771      0.088608     0.267516  0.257143
# 17516     0.041667      0.325301      0.113924     0.114650  0.228571
# 17517     0.116667      0.349398      0.139241     0.025478  0.200000
# 17518     0.016667      0.253012      0.101266     0.050955  0.142857
# 17519     0.008333      0.168675      0.075949     0.089172  0.142857
#
#        HR (% H.R.)  NOX (µg/m³N)  DD (grados)  RS (W/m³)  VV (m/s)  \
# 0         0.411111      0.043103     0.783333   0.000983      0.00
# 1         0.433333      0.043103     0.886111   0.000983      0.25
# 2         0.377778      0.038793     0.913889   0.000000      0.50
# 3         0.411111      0.043103     0.908333   0.000000      0.00
# 4         0.455556      0.051724     0.916667   0.000000      0.00
# ...            ...           ...          ...        ...       ...
# 17515     0.855556      0.081897     0.438889   0.000983      0.00
# 17516     0.933333      0.150862     0.680556   0.000983      0.00
# 17517     0.977778      0.219828     0.880556   0.000983      0.00
# 17518     1.000000      0.107759     0.850000   0.001967      0.00
# 17519     1.000000      0.064655     0.875000   0.001967      0.00
#
#        PM10 (µg/m³N)
# 0           0.098765
# 1           0.150617
# 2           0.251852
# 3           0.041975
# 4           0.009877
# ...              ...
# 17515       0.093827
# 17516       0.086420
# 17517       0.128395
# 17518       0.061728
# 17519       0.049383
#
# [17520 rows x 11 columns]

# %%
# %matplotlib inline

plot1=plt.figure(1)
sns.boxplot(y=normalized_al['NO (µg/m³N)'], whis =10)

plot2=plt.figure(2)
sns.boxplot(y=normalized_al['NO2 (µg/m³N)'], whis = 10)

plot3=plt.figure(3)
sns.boxplot(y=normalized_al['SO2 (µg/m³N)'], whis = 10)

plot4=plt.figure(4)
sns.boxplot(y=normalized_al['O3 (µg/m³N)'], whis = 10)

plot5=plt.figure(5)
sns.boxplot(y=normalized_al['NOX (µg/m³N)'], whis = 10)

plot6=plt.figure(6)
sns.boxplot(y=normalized_al['HR (% H.R.)'], whis = 10)

plot7=plt.figure(7)
sns.boxplot(y=normalized_al['DD (grados)'], whis = 10)

plot8=plt.figure(8)
sns.boxplot(y=normalized_al['RS (W/m³)'], whis = 10)

plot9=plt.figure(9)
sns.boxplot(y=normalized_al['PM10 (µg/m³N)'], whis = 10)

plot10=plt.figure(10)
sns.boxplot(y=normalized_al['TMP (ºC)'], whis = 10)

plot11=plt.figure(11)
sns.boxplot(y=normalized_al['VV (m/s)'], whis = 10)
# Out:
# <AxesSubplot:ylabel='VV (m/s)'>

# %%
normalized_al['Date'] = d[:-1]
normalized_al['Date'] = pd.to_datetime(normalized_al['Date'], format='%d-%m-%Y')
normalized_al['Month'] = d[:-1].strftime("%m")
normalized_al['Hour'] = d[:-1].strftime("%H")
normalized_al = normalized_al.set_index('Date')
normalized_al
# Out:
#                      NO (µg/m³N)  NO2 (µg/m³N)  SO2 (µg/m³N)  O3 (µg/m³N)  \
# Date
# 2018-01-01 00:00:00     0.016667      0.072289      0.088608     0.439490
# 2018-01-01 01:00:00     0.025000      0.072289      0.101266     0.414013
# 2018-01-01 02:00:00     0.016667      0.060241      0.126582     0.490446
# 2018-01-01 03:00:00     0.016667      0.072289      0.139241     0.484076
# 2018-01-01 04:00:00     0.016667      0.096386      0.113924     0.464968
# ...                          ...           ...           ...          ...
# 2019-12-31 19:00:00     0.016667      0.192771      0.088608     0.267516
# 2019-12-31 20:00:00     0.041667      0.325301      0.113924     0.114650
# 2019-12-31 21:00:00     0.116667      0.349398      0.139241     0.025478
# 2019-12-31 22:00:00     0.016667      0.253012      0.101266     0.050955
# 2019-12-31 23:00:00     0.008333      0.168675      0.075949     0.089172
#
#                      TMP (ºC)  HR (% H.R.)  NOX (µg/m³N)  DD (grados)  \
# Date
# 2018-01-01 00:00:00  0.428571     0.411111      0.043103     0.783333
# 2018-01-01 01:00:00  0.400000     0.433333      0.043103     0.886111
# 2018-01-01 02:00:00  0.371429     0.377778      0.038793     0.913889
# 2018-01-01 03:00:00  0.342857     0.411111      0.043103     0.908333
# 2018-01-01 04:00:00  0.314286     0.455556      0.051724     0.916667
# ...                       ...          ...           ...          ...
# 2019-12-31 19:00:00  0.257143     0.855556      0.081897     0.438889
# 2019-12-31 20:00:00  0.228571     0.933333      0.150862     0.680556
# 2019-12-31 21:00:00  0.200000     0.977778      0.219828     0.880556
# 2019-12-31 22:00:00  0.142857     1.000000      0.107759     0.850000
# 2019-12-31 23:00:00  0.142857     1.000000      0.064655     0.875000
#
#                      RS (W/m³)  VV (m/s)  PM10 (µg/m³N) Month Hour
# Date
# 2018-01-01 00:00:00   0.000983      0.00       0.098765    01   00
# 2018-01-01 01:00:00   0.000983      0.25       0.150617    01   01
# 2018-01-01 02:00:00   0.000000      0.50       0.251852    01   02
# 2018-01-01 03:00:00   0.000000      0.00       0.041975    01   03
# 2018-01-01 04:00:00   0.000000      0.00       0.009877    01   04
# ...                        ...       ...            ...   ...  ...
# 2019-12-31 19:00:00   0.000983      0.00       0.093827    12   19
# 2019-12-31 20:00:00   0.000983      0.00       0.086420    12   20
# 2019-12-31 21:00:00   0.000983      0.00       0.128395    12   21
# 2019-12-31 22:00:00   0.001967      0.00       0.061728    12   22
# 2019-12-31 23:00:00   0.001967      0.00       0.049383    12   23
#
# [17520 rows x 13 columns]

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5) 
After_imputation = imputer.fit_transform(normalized_al)
alc_knn = pd.DataFrame(After_imputation, columns = ['NO (µg/m³N)','NO2 (µg/m³N)','SO2 (µg/m³N)','O3 (µg/m³N)','TMP (ºC)','HR (% H.R.)','NOX (µg/m³N)','DD (grados)','RS (W/m³)','VV (m/s)','PM10 (µg/m³N)','Month','Hour'])
alc_knn
# Out:
#        NO (µg/m³N)  NO2 (µg/m³N)  SO2 (µg/m³N)  O3 (µg/m³N)  TMP (ºC)  \
# 0         0.016667      0.072289      0.088608     0.439490  0.428571
# 1         0.025000      0.072289      0.101266     0.414013  0.400000
# 2         0.016667      0.060241      0.126582     0.490446  0.371429
# 3         0.016667      0.072289      0.139241     0.484076  0.342857
# 4         0.016667      0.096386      0.113924     0.464968  0.314286
# ...            ...           ...           ...          ...       ...
# 17515     0.016667      0.192771      0.088608     0.267516  0.257143
# 17516     0.041667      0.325301      0.113924     0.114650  0.228571
# 17517     0.116667      0.349398      0.139241     0.025478  0.200000
# 17518     0.016667      0.253012      0.101266     0.050955  0.142857
# 17519     0.008333      0.168675      0.075949     0.089172  0.142857
#
#        HR (% H.R.)  NOX (µg/m³N)  DD (grados)  RS (W/m³)  VV (m/s)  \
# 0         0.411111      0.043103     0.783333   0.000983      0.00
# 1         0.433333      0.043103     0.886111   0.000983      0.25
# 2         0.377778      0.038793     0.913889   0.000000      0.50
# 3         0.411111      0.043103     0.908333   0.000000      0.00
# 4         0.455556      0.051724     0.916667   0.000000      0.00
# ...            ...           ...          ...        ...       ...
# 17515     0.855556      0.081897     0.438889   0.000983      0.00
# 17516     0.933333      0.150862     0.680556   0.000983      0.00
# 17517     0.977778      0.219828     0.880556   0.000983      0.00
# 17518     1.000000      0.107759     0.850000   0.001967      0.00
# 17519     1.000000      0.064655     0.875000   0.001967      0.00
#
#        PM10 (µg/m³N)  Month  Hour
# 0           0.098765    1.0   0.0
# 1           0.150617    1.0   1.0
# 2           0.251852    1.0   2.0
# 3           0.041975    1.0   3.0
# 4           0.009877    1.0   4.0
# ...              ...    ...   ...
# 17515       0.093827   12.0  19.0
# 17516       0.086420   12.0  20.0
# 17517       0.128395   12.0  21.0
# 17518       0.061728   12.0  22.0
# 17519       0.049383   12.0  23.0
#
# [17520 rows x 13 columns]

# %%
denormalized_alc=(alc_knn*(alc.max()-alc.min()))+alc.min()
denormalized_alc['Date'] = d[:-1]
denormalized_alc['Date'] = pd.to_datetime(denormalized_alc['Date'], format='%d-%m-%Y')
in_array = np.linspace(0, np.pi, 17520)
out_array = np.sin(in_array)
denormalized_alc['Month'] = 12*out_array
denormalized_alc['Hour'] = d[:-1].strftime("%H")
denormalized_alc.to_csv('al.csv',index=False)
denormalized_alc
# Out:
#        DD (grados)  HR (% H.R.) Hour         Month  NO (µg/m³N)  NO2 (µg/m³N)  \
# 0            282.0         47.0   00  0.000000e+00          3.0           8.0
# 1            319.0         49.0   01  2.151899e-03          4.0           8.0
# 2            329.0         44.0   02  4.303797e-03          3.0           7.0
# 3            327.0         47.0   03  6.455696e-03          3.0           8.0
# 4            330.0         51.0   04  8.607594e-03          3.0          10.0
# ...            ...          ...  ...           ...          ...           ...
# 17515        158.0         87.0   19  8.607594e-03          3.0          18.0
# 17516        245.0         94.0   20  6.455696e-03          6.0          29.0
# 17517        317.0         98.0   21  4.303797e-03         15.0          31.0
# 17518        306.0        100.0   22  2.151899e-03          3.0          23.0
# 17519        315.0        100.0   23  1.469576e-15          2.0          16.0
#
#        NOX (µg/m³N)  O3 (µg/m³N)  PM10 (µg/m³N)  RS (W/m³)  SO2 (µg/m³N)  \
# 0              13.0         70.0           41.0        2.0           7.0
# 1              13.0         66.0           62.0        2.0           8.0
# 2              12.0         78.0          103.0        1.0          10.0
# 3              13.0         77.0           18.0        1.0          11.0
# 4              15.0         74.0            5.0        1.0           9.0
# ...             ...          ...            ...        ...           ...
# 17515          22.0         43.0           39.0        2.0           7.0
# 17516          38.0         19.0           36.0        2.0           9.0
# 17517          54.0          5.0           53.0        2.0          11.0
# 17518          28.0          9.0           26.0        3.0           8.0
# 17519          18.0         15.0           21.0        3.0           6.0
#
#        TMP (ºC)  VV (m/s)                Date
# 0          19.0       1.0 2018-01-01 00:00:00
# 1          18.0       2.0 2018-01-01 01:00:00
# 2          17.0       3.0 2018-01-01 02:00:00
# 3          16.0       1.0 2018-01-01 03:00:00
# 4          15.0       1.0 2018-01-01 04:00:00
# ...         ...       ...                 ...
# 17515      13.0       1.0 2019-12-31 19:00:00
# 17516      12.0       1.0 2019-12-31 20:00:00
# 17517      11.0       1.0 2019-12-31 21:00:00
# 17518       9.0       1.0 2019-12-31 22:00:00
# 17519       9.0       1.0 2019-12-31 23:00:00
#
# [17520 rows x 14 columns]
